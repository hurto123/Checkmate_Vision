# %% [markdown]
# # 🚀 Chess AI Supervised Learning on Google Colab (GPU)
#
# This notebook sets up the environment, uploads your PGN file, and runs `train_sl_basic.py` on a GPU.
#
# **Steps**:
# 1️⃣ Install required packages (PyTorch with CUDA, python‑chess, numpy).
# 2️⃣ Upload `generated_rules.pgn` (or any PGN you want to train on).
# 3️⃣ Run the training script with the `--epochs` you prefer.
#
# You can adjust the number of epochs or batch size in the code cells below.

# %%
# Install dependencies (GPU‑enabled PyTorch)
# !pip install --quiet torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu118
# !pip install --quiet python-chess numpy

# %%
# Upload your PGN file (generated_rules.pgn)
from google.colab import files
uploaded = files.upload()  # Choose your PGN file

# %%
# Clone the project (or copy your local files)
# !git clone https://github.com/your-repo/Checkmate_Vision.git  # replace with actual repo if needed
# %cd Checkmate_Vision

# %%
# Ensure the uploaded PGN is in the project directory
import shutil, os
for fn in uploaded.keys():
    shutil.move(fn, os.path.join('..', fn))  # move to parent folder where script expects it

# %%
# Run supervised training on GPU
# !python train_sl_basic.py --pgn generated_rules.pgn --epochs 100 --batch_size 64
